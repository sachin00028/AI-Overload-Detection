# %% [markdown]
# <a href="https://colab.research.google.com/github/sachin00028/AI-Overload-Detection/blob/main/yolo_v3_overload_pro_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Mar 17 07:24:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15514, done.
# remote: Total 15514 (delta 0), reused 0 (delta 0), pack-reused 15514
# Receiving objects: 100% (15514/15514), 14.18 MiB | 21.20 MiB/s, done.
# Resolving deltas: 100% (10412/10412), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
! /usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
cd /content
# Out:
# /content

# %%
# !cp /content/drive/MyDrive/DL_pro/obj.zip ../

# %%
# !pwd
# Out:
# /content

# %%
# !unzip ../obj.zip -d data/
# Out:
# Archive:  ../obj.zip
#    creating: data/obj/
#   inflating: data/obj/over1.txt
#   inflating: data/obj/over28.jpg
#   inflating: data/obj/over5.jpg
#   inflating: data/obj/over2.jpg
#   inflating: data/obj/over7.jpg
#   inflating: data/obj/over3.jpg
#   inflating: data/obj/over4.jpg
#   inflating: data/obj/over12.jpg
#   inflating: data/obj/over10.jpg
#   inflating: data/obj/over21.jpg
#   inflating: data/obj/over23.jpg
#   inflating: data/obj/over6.jpg
#   inflating: data/obj/over26.jpg
#   inflating: data/obj/over8.jpg
#   inflating: data/obj/over14.jpg
#   inflating: data/obj/over20.jpg
#   inflating: data/obj/over13.jpg
#   inflating: data/obj/over22.jpg
#   inflating: data/obj/over18.jpg
#   inflating: data/obj/over9.jpg
#   inflating: data/obj/over15.jpg
#   inflating: data/obj/over24.jpg
#   inflating: data/obj/over16.jpg
#   inflating: data/obj/over11.jpg
#   inflating: data/obj/over25.jpg
#   inflating: data/obj/over19.jpg
#   inflating: data/obj/over27.jpg
# ...

# %%
# !cp /content/drive/MyDrive/DL_pro/obj.data ./data

# %%
# !cp /content/drive/MyDrive/DL_pro/obj.names ./data

# %%
# !cp /content/drive/MyDrive/DL_pro/yolov3_custom.cfg ./data

# %%
# !cp /content/drive/MyDrive/DL_pro/generate_train.py ./

# %%
cd /content
# Out:
# /content

# %%
# !python generate_train.py

# %%
# !ls data/
# Out:
# obj  obj.data  obj.names  train.txt  yolov3_custom.cfg

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2023-03-17 07:42:19--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  3.02MB/s    in 36s
#
# 2023-03-17 07:42:55 (4.33 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !pwd
# Out:
# /content

# %%
# !/content/darknet/darknet detector train /content/data/obj.data /content/data/yolov3_custom.cfg /content/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 46875, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.981380), count: 1, class_loss = 0.000002, iou_loss = 0.002147, total_loss = 0.002149
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...
